# %%
import numpy as np 
import pandas as pd 
import datetime

# %% [markdown]
# ## 生成随机人名

# %%
import random

# 定义姓氏列表
last_names = ['赵', '钱', '孙', '李', '周', '吴', '郑', '王', '冯', '陈', '褚', '卫', '蒋', '沈', '韩', '杨', '朱', '秦', '尤', '许',  
              '何', '吕', '施', '张', '孔', '曹', '严', '华', '金', '魏', '陶', '姜', '戚', '谢', '邹', '喻', '柏', '水', '窦', '章',  
              '云', '苏', '潘', '葛', '奚', '范', '彭', '郎', '鲁', '韦', '昌', '马', '苗', '凤', '花', '方', '俞', '任', '袁', '柳',  
              '酆', '鲍', '史', '唐', '费', '廉', '岑', '薛', '雷', '贺', '倪', '汤', '滕', '殷', '罗', '毕', '郝', '邬', '安', '常',  
              '乐', '于', '时', '傅', '皮', '卞', '齐', '康', '伍', '余', '元', '卜', '顾', '孟', '平', '黄', '和', '穆', '萧', '尹',  
              '姚', '邵', '湛', '汪', '祁', '毛', '禹', '狄', '米', '贝', '明', '臧', '计', '伏', '成', '戴', '谈', '宋', '茅', '庞',  
              '熊', '纪', '舒', '屈', '项', '祝', '董', '梁']

# 定义名词列表  
first_names = ['健','军','伟','刚', '勇','毅','俊','峰','强','军','杰','健']

# 生成不重复随机人名 
names = set()
while len(names) < 500:
    name = random.choice(last_names) + random.choice(first_names)
    names.add(name)

print(list(names))
# Out:
# ['袁军', '禹军', '茅勇', '戚军', '华健', '潘强', '计毅', '贝刚', '尹杰', '孟健', '米健', '舒刚', '苏健', '祝勇', '郝俊', '袁杰', '沈强', '茅峰', '纪杰', '米伟', '贝杰', '臧勇', '时军', '陶强', '钱勇', '喻健', '项强', '贝军', '滕军', '汤峰', '傅杰', '屈毅', '史军', '陶峰', '舒伟', '庞杰', '顾强', '孙峰', '尤毅', '庞军', '纪健', '鲍峰', '喻刚', '傅刚', '姚伟', '时刚', '于杰', '董健', '尹俊', '云健', '齐刚', '于健', '庞强', '蒋峰', '费刚', '伏勇', '谢刚', '彭伟', '乐勇', '庞毅', '梁军', '臧军', '庞俊', '伏峰', '殷伟', '葛军', '戚健', '安毅', '钱军', '柏杰', '成军', '酆伟', '李伟', '卞军', '平杰', '齐健', '秦军', '项伟', '柏军', '花强', '湛健', '薛军', '雷俊', '范伟', '屈军', '钱刚', '戴健', '尤俊', '姚峰', '董俊', '萧峰', '唐健', '殷峰', '苗健', '昌俊', '史健', '费军', '穆强', '郎健', '于毅', '许杰', '周俊', '卞强', '元勇', '袁峰', '花军', '华军', '孙俊', '孟军', '湛杰', '计俊', '纪伟', '康强', '殷强', '花峰', '章军', '姜俊', '于勇', '安军', '毛军', '庞刚', '昌毅', '狄俊', '成毅', '余刚', '李刚', '禹刚', '吴峰', '毕伟', '苗峰', '华伟', '魏毅', '酆俊', '郑军', '梁勇', '舒俊', '毛刚', '何俊', '廉强', '苗军', '傅峰', '杨伟', '孟峰', '成伟', '马刚', '熊军', '傅健', '谈杰', '谈健', '毛健', '廉伟', '祁军', '康毅', '杨健', '汪军', '冯军', '臧杰', '邬强', '费毅', '方勇', '朱刚', '罗勇', '伏俊', '蒋勇', '宋杰', '屈杰', '姚俊', '施军', '祁俊', '奚健', '尤杰', '成强', '顾健', '秦勇', '乐健', '平健', '金刚', '任健', '袁俊', '舒毅', '宋勇', '谢杰', '邬峰', '元俊', '孔俊', '康伟', '王健', '宋毅', '华毅', '苗杰', '冯刚', '窦勇', '贺峰', '禹伟', '杨毅', '伏军', '邹杰', '穆伟', '乐俊', '湛强', '贺杰', '云毅', '周杰', '雷刚', '戚峰', '常峰', '余杰', '米毅', '傅勇', '元杰', '柳勇', '卫健', '秦毅', '陈杰', '史伟', '屈勇', '姜毅', '戴杰', '皮俊', '卜军', '成刚', '明毅', '余伟', '郎强', '彭杰', '傅毅', '姜健', '皮军', '安勇', '苏峰', '施峰', '吕俊', '米军', '屈刚', '康俊', '昌军', '于强', '黄刚', '祝峰', '周勇', '禹峰', '蒋杰', '唐军', '冯俊', '窦俊', '贝强', '施健', '庞伟', '魏军', '范峰', '彭刚', '华强', '孙刚', '任强', '沈军', '尤健', '卞杰', '禹杰', '张伟', '鲍健', '赵俊', '舒峰', '卫俊', '喻毅', '方强', '明俊', '顾军', '卫强', '吕峰', '尹健', '苏杰', '时伟', '常健', '郑杰', '水俊', '毕强', '章杰', '秦俊', '顾刚', '邵峰', '云军', '奚峰', '凤勇', '皮强', '孙强', '祝健', '昌伟', '柏健', '宋军', '郝强', '滕俊', '钱俊', '柳健', '潘刚', '沈勇', '伏伟', '云杰', '朱勇', '邬健', '许峰', '茅伟', '汤军', '郎杰', '梁杰', '孙勇', '乐峰', '孙健', '鲁峰', '毕健', '戴伟', '黄毅', '俞毅', '郎峰', '舒杰', '邹峰', '祁健', '张强', '水军', '廉刚', '唐刚', '禹健', '和强', '伏健', '卫勇', '谈强', '安伟', '柳军', '秦健', '明峰', '郝勇', '卫军', '卞健', '毕峰', '钱峰', '薛强', '俞强', '金军', '马健', '陶杰', '康健', '贝勇', '钱健', '袁健', '伍强', '董峰', '曹军', '湛勇', '伍刚', '曹峰', '邹健', '吴毅', '王刚', '潘军', '庞健', '韦军', '花勇', '华俊', '戴军', '穆杰', '费健', '狄刚', '葛勇', '孔毅', '元健', '顾杰', '范俊', '邬毅', '舒健', '韩毅', '陈健', '金强', '柳杰', '尤强', '严刚', '倪军', '任勇', '贺强', '萧伟', '和健', '鲍强', '魏健', '尤勇', '魏勇', '吕刚', '毕俊', '宋健', '臧毅', '邹军', '范军', '滕健', '谢健', '岑军', '蒋强', '章峰', '鲁毅', '昌健', '卜俊', '伍健', '凤强', '杨杰', '俞健', '邵毅', '沈毅', '宋俊', '时杰', '周强', '明刚', '何杰', '黄杰', '康刚', '倪毅', '尹强', '皮杰', '戴俊', '计勇', '戚刚', '杨强', '康杰', '蒋伟', '康军', '姚军', '严勇', '祝杰', '明勇', '于伟', '常俊', '董毅', '滕峰', '郎军', '廉毅', '郝健', '卜健', '和峰', '殷军', '乐军', '米峰', '赵健', '时强', '明强', '姜刚', '吕健', '苗俊', '雷军', '李健', '韩强', '马俊', '昌杰', '孙毅', '傅军', '褚健', '章强', '邬勇', '元军', '董杰', '邬军', '贺俊', '云强', '湛俊', '马军', '水健', '云俊', '李俊', '曹俊', '葛毅', '韦俊', '岑健', '雷勇', '花健', '周刚', '施伟', '贺健', '廉杰', '皮峰', '皮健', '时健', '张俊', '陶勇', '臧刚', '汤健', '潘杰', '和俊', '薛俊', '史杰', '邵伟', '鲁强', '纪军', '鲁伟', '苗刚', '舒强', '于峰', '严健', '熊刚', '窦军', '罗杰', '毛毅', '孔军', '王伟', '奚勇', '计杰', '喻杰']

# %% [markdown]
# 生成随机时间

# %% [markdown]
# 将时间转换为date格式

# %%
import numpy as np
import random

def getRandomDate(year_begin, year_end):
    # 生成随机年份
    random_year = random.randint(year_begin, year_end)

    # 生成随机月份 
    random_month = random.randint(1, 12)

    # 生成随机天数
    # 闰年2月29天,平年2月28天  
    if random_month == 2:
        if ((random_year % 4 == 0) and (random_year % 100 != 0)) or (random_year % 400 == 0):
            random_day = random.randint(1, 29)
        else:
            random_day = random.randint(1, 28)
    elif random_month in [1, 3, 5, 7, 8, 10, 12]:
        random_day = random.randint(1, 31)
    else:
        random_day = random.randint(1, 30) 

    return np.datetime64(f'{random_year}-{random_month:02}-{random_day:02}')

def formatDate(date):
    return np.datetime_as_string(date, unit='M').replace('-', '.')

print(getRandomDate(1963, 2000))
# Out:
# 1993-06-17

# %%
# 定义人员表格数据
jobs = ['一级调研员','二级调研员','三级调研员','四级调研员','一级主任科员','二级主任科员','三级主任科员','四级主任科员','一级科员','二级科员', '副处长' ,'处长']
jobIds = list(range(1, len(jobs)))
jobWeights = list(reversed(jobIds)) # 权重是id的倒置
jobWeightResult = random.choices(jobIds, weights=jobWeights, k=len(names))
sex = ['男', '女']
members = []
for idx, name in enumerate(names): 
    birth_date = getRandomDate(1955, 2000)
    entry_date = getRandomDate(birth_date.astype(datetime.date).year+20, 2020)
    last_promotion_date = getRandomDate(entry_date.astype(datetime.date).year+2, 2022)
    rec = {
        '姓名': name,
        '现工作单位及职务': jobs[jobWeightResult[idx]],
        '性别': sex[random.randint(0, 1)],
        '民族': '汉',
				'籍贯': '四川成都',
				'出生年月': formatDate(birth_date),
				'参加工作时间': formatDate(entry_date),
				'任现职务时间': formatDate(last_promotion_date),
				'任现职级时间': formatDate(last_promotion_date),
				'入党时间': '1997.02',
				'全日制学历学位': '大学法学学生',
				'全日制毕业院校及专业': 'xx学院xx专业',
				'在职学历学位': '大学',
				'在职毕业院校及专业': 'xx大学xx专业',
				'任二主时间': '',
    }
    members.append(rec)

# %%
# 将字典转化为DataFrame
df = pd.DataFrame(members)
df.groupby('现工作单位及职务').size().head(100)
# df.head(100)
# Out:
# 现工作单位及职务
# 一级主任科员    53
# 一级科员      31
# 三级主任科员    49
# 三级调研员     65
# 二级主任科员    54
# 二级科员      17
# 二级调研员     84
# 副处长       15
# 四级主任科员    43
# 四级调研员     82
# 处长         7
# dtype: int64

# %%
# 将DataFrame导出为Excel文件 
df.to_csv('../input/member-list/civil_list.csv', index=False)
